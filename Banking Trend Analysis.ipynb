# %%
#--- Import Pandas ---
import pandas as pd

#--- Read in dataset ----
df = pd.read_csv("/content/drive/MyDrive/datasets and projects/user_nodes.csv")

df
# Out:
#       id_  area_id_  node_id_    act_date  deact_date  has_loan  is_act
# 0       1         3         4  02-01-2020  03-01-2020         1       0
# 1       2         3         5  03-01-2020  17-01-2020         0       1
# 2       3         5         4  27-01-2020  18-02-2020         0       0
# 3       4         5         4  07-01-2020  19-01-2020         1       1
# 4       5         3         3  15-01-2020  23-01-2020         0       1
# ...   ...       ...       ...         ...         ...       ...     ...
# 3638  261         2         4  25-01-2020  07-02-2020         1       0
# 3639  262         3         3  04-01-2020  13-01-2020         0       0
# 3640  263         2         3  16-01-2020  16-01-2020         0       1
# 3641  264         4         1  16-01-2020  31-01-2020         0       0
# 3642  265         1         2  08-01-2020  28-01-2020         1       0
#
# [3643 rows x 7 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
duplicates = df.duplicated().sum()

duplicates
# Out:
# 143

# %%
null_values = df.isnull().sum()

null_values
# Out:
# id_           0
# area_id_      0
# node_id_      0
# act_date      0
# deact_date    0
# has_loan      0
# is_act        0
# dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#       id_  area_id_  node_id_    act_date  deact_date  has_loan  is_act
# 0       1         3         4  02-01-2020  03-01-2020         1       0
# 1       2         3         5  03-01-2020  17-01-2020         0       1
# 2       3         5         4  27-01-2020  18-02-2020         0       0
# 3       4         5         4  07-01-2020  19-01-2020         1       1
# 4       5         3         3  15-01-2020  23-01-2020         0       1
# ...   ...       ...       ...         ...         ...       ...     ...
# 3495  496         3         4  25-02-2020  31-12-2021         0       0
# 3496  497         5         4  27-05-2020  31-12-2021         0       1
# 3497  498         1         2  05-04-2020  31-12-2021         0       0
# 3498  499         5         1  03-02-2020  31-12-2021         1       1
# 3499  500         2         2  15-04-2020  31-12-2021         0       1
#
# [3500 rows x 7 columns]

# %%
df = df.drop(["has_loan", "is_act"], axis=1)
df
# Out:
#       id_  area_id_  node_id_    act_date  deact_date
# 0       1         3         4  02-01-2020  03-01-2020
# 1       2         3         5  03-01-2020  17-01-2020
# 2       3         5         4  27-01-2020  18-02-2020
# 3       4         5         4  07-01-2020  19-01-2020
# 4       5         3         3  15-01-2020  23-01-2020
# ...   ...       ...       ...         ...         ...
# 3495  496         3         4  25-02-2020  31-12-2021
# 3496  497         5         4  27-05-2020  31-12-2021
# 3497  498         1         2  05-04-2020  31-12-2021
# 3498  499         5         1  03-02-2020  31-12-2021
# 3499  500         2         2  15-04-2020  31-12-2021
#
# [3500 rows x 5 columns]

# %%
df =df.rename(columns={"id_": "consumer_id",
                       "node_id_": "node_id",
                       "act_date": "start_date",
                       "deact_date": "end_date"})
df = df.rename(columns={"area_id_" : "region_id"})
df
# Out:
#       consumer_id  region_id  node_id  start_date    end_date
# 0               1          3        4  02-01-2020  03-01-2020
# 1               2          3        5  03-01-2020  17-01-2020
# 2               3          5        4  27-01-2020  18-02-2020
# 3               4          5        4  07-01-2020  19-01-2020
# 4               5          3        3  15-01-2020  23-01-2020
# ...           ...        ...      ...         ...         ...
# 3495          496          3        4  25-02-2020  31-12-2021
# 3496          497          5        4  27-05-2020  31-12-2021
# 3497          498          1        2  05-04-2020  31-12-2021
# 3498          499          5        1  03-02-2020  31-12-2021
# 3499          500          2        2  15-04-2020  31-12-2021
#
# [3500 rows x 5 columns]

# %%
import pandas as pd

df1 = pd.read_csv("/content/drive/MyDrive/datasets and projects/user_transactions.csv")

# %%
df1
# Out:
#       id_      t_date   t_type  t_amt has_credit_card account_type
# 0     312  20-01-2020  deposit    485             Yes      Savings
# 1     376  03-01-2020  deposit    706              No      Current
# 2     188  13-01-2020  deposit    601              No      Savings
# 3     138  11-01-2020  deposit    520              No       Salary
# 4     373  18-01-2020  deposit    596              No       Salary
# ...   ...         ...      ...    ...             ...          ...
# 5942  281  06-01-2020  deposit    616             Yes      Current
# 5943  391  15-01-2020  deposit    219             Yes      Current
# 5944   45  14-01-2020  deposit    650              No      Current
# 5945   49  04-01-2020  deposit    432              No      Savings
# 5946  473  17-01-2020  deposit    657              No      Current
#
# [5947 rows x 6 columns]

# %%
null_value = df1.isnull().sum()
null_value
# Out:
# id_                0
# t_date             0
# t_type             0
# t_amt              0
# has_credit_card    0
# account_type       0
# dtype: int64

# %%
duplicate = df1.duplicated().sum()
duplicate
# Out:
# 79

# %%
df1= df1.drop_duplicates()
df1
# Out:
#       id_      t_date   t_type  t_amt has_credit_card account_type
# 0     312  20-01-2020  deposit    485             Yes      Savings
# 1     376  03-01-2020  deposit    706              No      Current
# 2     188  13-01-2020  deposit    601              No      Savings
# 3     138  11-01-2020  deposit    520              No       Salary
# 4     373  18-01-2020  deposit    596              No       Salary
# ...   ...         ...      ...    ...             ...          ...
# 5863  155  10-01-2020  deposit    712             Yes      Savings
# 5864  398  01-01-2020  deposit    196              No      Current
# 5865  255  14-01-2020  deposit    563             Yes      Savings
# 5866  185  29-01-2020  deposit    626             Yes      Savings
# 5867  309  13-01-2020  deposit    995             Yes      Savings
#
# [5868 rows x 6 columns]

# %%
df1 = df1.drop(["has_credit_card","account_type"], axis=1)
df1
# Out:
#       id_      t_date   t_type  t_amt
# 0     312  20-01-2020  deposit    485
# 1     376  03-01-2020  deposit    706
# 2     188  13-01-2020  deposit    601
# 3     138  11-01-2020  deposit    520
# 4     373  18-01-2020  deposit    596
# ...   ...         ...      ...    ...
# 5863  155  10-01-2020  deposit    712
# 5864  398  01-01-2020  deposit    196
# 5865  255  14-01-2020  deposit    563
# 5866  185  29-01-2020  deposit    626
# 5867  309  13-01-2020  deposit    995
#
# [5868 rows x 4 columns]

# %%
df1 =  df1.rename(columns={"id_":"consumer_id","t_date": "transaction_date", "t_type": "transaction_type", "t_amt": "transaction_amount"})
df
# Out:
#       consumer_id  region_id  node_id  start_date    end_date
# 0               1          3        4  02-01-2020  03-01-2020
# 1               2          3        5  03-01-2020  17-01-2020
# 2               3          5        4  27-01-2020  18-02-2020
# 3               4          5        4  07-01-2020  19-01-2020
# 4               5          3        3  15-01-2020  23-01-2020
# ...           ...        ...      ...         ...         ...
# 3495          496          3        4  25-02-2020  31-12-2021
# 3496          497          5        4  27-05-2020  31-12-2021
# 3497          498          1        2  05-04-2020  31-12-2021
# 3498          499          5        1  03-02-2020  31-12-2021
# 3499          500          2        2  15-04-2020  31-12-2021
#
# [3500 rows x 5 columns]
